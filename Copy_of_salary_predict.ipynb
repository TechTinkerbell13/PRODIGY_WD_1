# %% [markdown]
# <a href="https://colab.research.google.com/github/TechTinkerbell13/PRODIGY_WD_1/blob/main/Copy_of_salary_predict.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
dataset=pd.read_csv('/content/Salary_Data (1).csv')
print(dataset)
# Out:
#     YearsExperience    Salary
# 0               1.1   39343.0
# 1               1.3   46205.0
# 2               1.5   37731.0
# 3               2.0   43525.0
# 4               2.2   39891.0
# 5               2.9   56642.0
# 6               3.0   60150.0
# 7               3.2   54445.0
# 8               3.2   64445.0
# 9               3.7   57189.0
# 10              3.9   63218.0
# 11              4.0   55794.0
# 12              4.0   56957.0
# 13              4.1   57081.0
# 14              4.5   61111.0
# 15              4.9   67938.0
# 16              5.1   66029.0
# 17              5.3   83088.0
# 18              5.9   81363.0
# 19              6.0   93940.0
# 20              6.8   91738.0
# 21              7.1   98273.0
# 22              7.9  101302.0
# 23              8.2  113812.0
# 24              8.7  109431.0
# 25              9.0  105582.0
# 26              9.5  116969.0
# 27              9.6  112635.0
# 28             10.3  122391.0
# 29             10.5  121872.0

# %%
x=dataset.iloc[:,:-1].values
y=dataset.iloc[:,-1].values
print(x)
print(y)
# Out:
# [[ 1.1]
#  [ 1.3]
#  [ 1.5]
#  [ 2. ]
#  [ 2.2]
#  [ 2.9]
#  [ 3. ]
#  [ 3.2]
#  [ 3.2]
#  [ 3.7]
#  [ 3.9]
#  [ 4. ]
#  [ 4. ]
#  [ 4.1]
#  [ 4.5]
#  [ 4.9]
#  [ 5.1]
#  [ 5.3]
#  [ 5.9]
#  [ 6. ]
#  [ 6.8]
#  [ 7.1]
#  [ 7.9]
#  [ 8.2]
#  [ 8.7]
#  [ 9. ]
#  [ 9.5]
#  [ 9.6]
#  [10.3]
#  [10.5]]
# [ 39343.  46205.  37731.  43525.  39891.  56642.  60150.  54445.  64445.
#   57189.  63218.  55794.  56957.  57081.  61111.  67938.  66029.  83088.
#   81363.  93940.  91738.  98273. 101302. 113812. 109431. 105582. 116969.
#  112635. 122391. 121872.]

# %%
plt.xlabel('area')
plt.ylabel('price')
plt.title('Area vs. Price')
plt.scatter(x,y,color='red',marker='+')

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3)
print(x_train.shape,  x_test.shape)
# Out:
# (21, 1) (9, 1)

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=model.predict(x_test)
print(y_pred)
print(y_train)
# Out:
# [ 64254.10416003 117584.40134082 111870.44092859  64254.10416003
#   90919.25275042  76634.35171986  53778.51007095  61397.12395392
#   45207.56945261]
# [ 67938. 121872.  57081.  81363.  63218.  98273. 113812. 116969. 101302.
#   54445.  64445.  46205.  39343.  39891.  61111.  60150.  66029. 122391.
#   37731. 109431.  93940.]

# %%
accuracy=model.score(x_test,y_test)
print(accuracy)
# Out:
# 0.9482329074966037

# %% [markdown]
# Plot the Regression Curve

# %%
plt.scatter(x_train,y_train,color='red',marker='+')
plt.xlabel('YearsExperience')
plt.ylabel('Salary')
plt.title('YearsExperience vs Salary (Training data) ')
plt.plot(x_train, model.predict(x_train),color='blue')
plt.show()

plt.scatter(x_test,y_test,color='red',marker='+')
plt.xlabel('YearsExperience')
plt.ylabel('Salary')
plt.title('YearsExperience vs Salary (Testing data) ')
plt.plot(x_test, model.predict(x_test),color='blue')
plt.show()

# %% [markdown]
# Predict data from user through manual input

# %%
WorkExperience = int(input("How many years have you worked in this field of expertise?"))
SalaryEarned = model.predict(np.array([[WorkExperience]]))
print('Estimated salary' + str(WorkExperience) + 'years of experience are ' + str(SalaryEarned[0]))
# Out:
# How many years have you worked in this field of expertise?100
# Estimated salary100years of experience are 978487.7701162756
